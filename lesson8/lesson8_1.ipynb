# %%
sql = """SELECT "stationCode",name,"stationAddrTw",日期,進站人數,出站人數
FROM "台鐵車站資訊" LEFT JOIN "每日各站進出站人數" ON "stationCode" = "車站代碼"
WHERE "stationAddrTw" LIKE '%臺北市%';"""

print(sql)
# Out:
# SELECT "stationCode",name,"stationAddrTw",日期,進站人數,出站人數
# FROM "台鐵車站資訊" LEFT JOIN "每日各站進出站人數" ON "stationCode" = "車站代碼"
# WHERE "stationAddrTw" LIKE '%臺北市%';

# %%
#建立變數
n = 5
m = 10.0
x = '5'
print(type(n))
print(type(m))
print(type(x))

print("===========")

n = 10
m = 15.0
x = '50'
print(n)
print(m)
print(x)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# ...
# 10
# 15.0
# 50

# %%
#建立tuple
student1 = (87, 76, 65, 78, 92)#Sequence(串列資料)
student1
type(student1)
# Out:
# tuple

# %%
#建立list
student2 = [87, 76, 65, 78, 92]#Sequence(序列資料)
student2
type(student2)

#使用subscript取出元素值
student2[0]
student2[1]
student2[2]
student2[3]
student2[4]
#student2[5] # 超出索引會出錯
# Out:
# 92

# %%
#建立dict(dictionary)
student3 = {'chinese':67,'english':75,'math':89,'history':87,'discovery':92} #mapping(映射資料)
type(student3)
#使用subscript取出值
student3['math']
student3['history']
# Out:
# 87

# %%
#tuple的拆解法
m, n = 78, 92
m
n
# Out:
# 92

# %%
#建立4個學生的list
students1 = [87, 76, 65, 78, 92] #Sequence(序列資料)
students2 = [67, 75, 89, 87, 92] #Sequence(序列資料)
students3 = [88, 90, 85, 80, 95] #Sequence(序列資料)
students4 = [90, 85, 88, 92, 80] #Sequence(序列資料)

#建立4個學生的dict
students5 = {'chinese':87,'english':76,'math':65,'history':78,'discovery':92} #mapping(映射資料)
students6 = {'chinese':67,'english':75,'math':89,'history':87,'discovery':92}
students7 = {'chinese':88,'english':90,'math':85,'history':80,'discovery':95}
students8 = {'chinese':90,'english':85,'math':88,'history':92,'discovery':80}

#建立students的list,包含4個學生的dict
students = [students5, students6, students7, students8] #Sequence(序列資料)
students

students[0]['chinese']
students[2]['chinese']
# Out:
# 88
